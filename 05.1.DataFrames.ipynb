# %% [markdown]
# # Sección 5: DATAFRAMES
# ## Importando Dataset

# %%
#importamos panda, el mejor paquete de Python
import pandas as pd

# %% [markdown]
# ## MÉTODO 1
# -Especificar ruta completa al archivo

# %%
#método 1
#para windows: usa la funcion read del paquete pd(pandas) para llamar al dataset que hemos llamado datos
#para la ruta del archivo se usa la doble \\ para indicar la ruta en windows
#en mi caso C:\Users\CPU\Jupiter-docus\Seccion5-Datos y luego el nombre del archivo

datos=pd.read_csv('C:\\Users\\CPU\\Jupiter-docus\\Seccion5-Datos\\DatosDemograficos.csv')
#Tambien sirve con la nomencaltura de mac pero mejor usar la doble \\ para archivos en windows.

#datos=pd.read_csv('/Users/CPU/Jupiter-docus/Seccion5-Datos/DatosDemograficos.csv')
#Mac
#datos=pd.read_csv('/Users/CPU/Jupiter-docus/Seccion5-Datos/DatosDemograficos.csv')

# %%
datos
#vemos los datos del csv
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %% [markdown]
# ## MÉTODO 2
# - Cambiando el Working Directory

# %%
import os

# %%
print(os.getcwd())  #nos indica donde está nuestro directorio de trabajo ahora
# Out:
# C:\Users\CPU\Jupiter-docus

# %%
#si ponemos el archivo csv dentro de esa carpeta podemos acceder a el sin necesidad de poner la ruta a todo
#C:\Users\CPU\Jupiter-docus

# %%
#para Windows:
os.chdir('C:\\Users\\CPU\\Jupiter-docus\\Seccion5-Datos')
#igual que antes también funciona ahora la nomenclatura mac sin problemas
#os.chdir('C:/Users/CPU/Jupiter-docus/Seccion5-Datos')
#para mac:
#os.chdir('/Users/CPU/ruta')

# %%
print(os.getcwd())
# Out:
# C:\Users\CPU\Jupiter-docus\Seccion5-Datos

# %%
#ahora la ruta ha cambiado y coge los archivos de esa carpeta

# %%
datos2 = pd.read_csv('DatosDemograficos.csv')  
#al cambiar la carpeta de trabajo ya no es necesario escribir toda la ruta para acceder al archivo, solo se pone el nombre
#esto hace el código mucho más limpio

# %%
datos2
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %% [markdown]
# ## EXPLORANDO LOS DATOS
# Ya hemos importado los datos, ahora vamos a explorar esos datos de DataFrame
#
# <ul>
#     <li>Número de filas: <b>len(datos)</b></li>
#     <li>Ver columnas: <b>datos.columns</b></li>
#     <li>Número de columnas: <b>len(datos.columns)</b></li>
#     <li>Ver filas superiores: <b>datos.head()</b> </li>
#     <li>Ver filas inferiores: <b>datos.tail()</b></li>
#     <li>Info de las columnas: <b>datos.info() </b></li>
#     <li>Estadísticas:<b>datos.describe()</b></li>
#     <li>Transponer los datos: <b>datos.describe().transpose()<b></li>
#
# </ul>

# %%
#1 Importar los datos
datos=pd.read_csv('C:\\Users\\CPU\\Jupiter-docus\\Seccion5-Datos\\DatosDemograficos.csv')

# %%
#2 Número de Filas (incluye las cabezeras)
len(datos)    #195filas

#esto puede servir para ver si hay datos alterados o si faltan datos x importar.
# Out:
# 195

# %%
#3 Número de Columnas, nos muestra las columnas de nuestro archivo, las cabeceras
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
len(datos.columns)
# Out:
# 5

# %%
#5 Filas superiores
datos.head()   #nos da las primeras 5 filas.
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
#
#    Usuarios de Internet   Grupo de ingresos
# 0                  78.9        Ingreso alto
# 1                   5.9        Ingreso bajo
# 2                  19.1  Ingreso medio alto
# 3                  57.2  Ingreso medio alto
# 4                  88.0        Ingreso alto

# %%
datos.head(10)  #cambiamos el numero de filas a monstrar
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
# 5             Argentina            ARG             17.716
# 6               Armenia            ARM             13.308
# 7   Antigua and Barbuda            ATG             16.447
# 8             Australia            AUS             13.200
# 9               Austria            AUT              9.400
#
#    Usuarios de Internet   Grupo de ingresos
# 0               78.9000        Ingreso alto
# 1                5.9000        Ingreso bajo
# 2               19.1000  Ingreso medio alto
# 3               57.2000  Ingreso medio alto
# 4               88.0000        Ingreso alto
# 5               59.9000        Ingreso alto
# ...

# %%
#filas inferiores
datos.tail()  #igual que antes se puede especificar
# Out:
#       Nombre del Pais Codigo de Pais  Tasa de Natalidad  Usuarios de Internet  \
# 190       Yemen, Rep.            YEM             32.947                  20.0
# 191      South Africa            ZAF             20.850                  46.5
# 192  Congo, Dem. Rep.            COD             42.394                   2.2
# 193            Zambia            ZMB             40.471                  15.4
# 194          Zimbabwe            ZWE             35.715                  18.5
#
#       Grupo de ingresos
# 190  Ingreso medio bajo
# 191  Ingreso medio alto
# 192        Ingreso bajo
# 193  Ingreso medio bajo
# 194        Ingreso bajo

# %%
#7 Información de las columnas
datos.info()    #es igual que la funcion str de R (aunque str da más información)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nombre del Pais       195 non-null    object
#  1   Codigo de Pais        195 non-null    object
#  2   Tasa de Natalidad     195 non-null    float64
#  3   Usuarios de Internet  195 non-null    float64
#  4   Grupo de ingresos     195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8 Obtener estadisticas de las columnas

datos.describe()   #func similar al summary en R
# Out:
#        Tasa de Natalidad  Usuarios de Internet
# count         195.000000            195.000000
# mean           21.469928             42.076471
# std            10.605467             29.030788
# min             7.900000              0.900000
# 25%            12.120500             14.520000
# 50%            19.680000             41.000000
# 75%            29.759500             66.225000
# max            49.661000             96.546800

# %%
#transponer los datos
datos.describe().transpose()
# Out:
#                       count       mean        std  min      25%    50%  \
# Tasa de Natalidad     195.0  21.469928  10.605467  7.9  12.1205  19.68
# Usuarios de Internet  195.0  42.076471  29.030788  0.9  14.5200  41.00
#
#                           75%      max
# Tasa de Natalidad     29.7595  49.6610
# Usuarios de Internet  66.2250  96.5468

# %% [markdown]
# ---

# %% [markdown]
# <h2>Cambiar el nombre a columnas en un DataFrame</h2>

# %%
datos.head()
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
#
#    Usuarios de Internet   Grupo de ingresos
# 0                  78.9        Ingreso alto
# 1                   5.9        Ingreso bajo
# 2                  19.1  Ingreso medio alto
# 3                  57.2  Ingreso medio alto
# 4                  88.0        Ingreso alto

# %%
#en este caso los nombres no están estandarizados. tenemos que hacer limpieza, entonces cambiamos el name a las columns
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
datos.columns = ['NombrePais','CodigoPais','TasaNatalidad','UsuariosInternet','GrupoIngresos']

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %% [markdown]
# ---

# %% [markdown]
# ## SUBCONJUNTOS DE DATAFRAMES EN PANDAS.
